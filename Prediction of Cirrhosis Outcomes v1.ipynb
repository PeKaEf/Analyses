# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

train_df = pd.read_csv("C:/Users/pfali/Downloads/playground-series-s3e26/train.csv")
test_df = pd.read_csv("C:/Users/pfali/Downloads/playground-series-s3e26/test.csv")

train_df.head()
# Out:
#    id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0   0     999  D-penicillamine  21532   M       N            N       N     N
# 1   1    2574          Placebo  19237   F       N            N       N     N
# 2   2    3428          Placebo  13727   F       N            Y       Y     Y
# 3   3    2576          Placebo  18460   F       N            N       N     N
# 4   4     788          Placebo  16658   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        2.3        316.0     3.35   172.0    1601.0  179.80           63.0
# 1        0.9        364.0     3.54    63.0    1440.0  134.85           88.0
# 2        3.3        299.0     3.55   131.0    1029.0  119.35           50.0
# 3        0.6        256.0     3.50    58.0    1653.0   71.30           96.0
# 4        1.1        346.0     3.65    63.0    1181.0  125.55           96.0
#
#    Platelets  Prothrombin  Stage Status
# ...

# %%
train_df.describe(include='all')
# Out:
#                  id       N_Days     Drug           Age   Sex Ascites  \
# count   7905.000000  7905.000000     7905   7905.000000  7905    7905
# unique          NaN          NaN        2           NaN     2       2
# top             NaN          NaN  Placebo           NaN     F       N
# freq            NaN          NaN     4010           NaN  7336    7525
# mean    3952.000000  2030.173308      NaN  18373.146490   NaN     NaN
# std     2282.121272  1094.233744      NaN   3679.958739   NaN     NaN
# min        0.000000    41.000000      NaN   9598.000000   NaN     NaN
# 25%     1976.000000  1230.000000      NaN  15574.000000   NaN     NaN
# 50%     3952.000000  1831.000000      NaN  18713.000000   NaN     NaN
# 75%     5928.000000  2689.000000      NaN  20684.000000   NaN     NaN
# max     7904.000000  4795.000000      NaN  28650.000000   NaN     NaN
#
#        Hepatomegaly Spiders Edema    Bilirubin  Cholesterol      Albumin  \
# ...

# %%
train_df.isnull().sum()
# Out:
# id               0
# N_Days           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# Status           0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# id               0
# N_Days           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
train_df.dtypes
# Out:
# id                 int64
# N_Days             int64
# Drug              object
# Age                int64
# Sex               object
# Ascites           object
# Hepatomegaly      object
# Spiders           object
# Edema             object
# Bilirubin        float64
# Cholesterol      float64
# Albumin          float64
# Copper           float64
# Alk_Phos         float64
# SGOT             float64
# Tryglicerides    float64
# Platelets        float64
# Prothrombin      float64
# Stage            float64
# Status            object
# dtype: object

# %%
train_df['Sex'].replace(['M','F'],[0,1],inplace=True)
train_df['Ascites'].replace(['N','Y'],[0,1],inplace=True)
train_df['Hepatomegaly'].replace(['N','Y'],[0,1],inplace=True)
train_df['Spiders'].replace(['N','Y'],[0,1],inplace=True)
train_df['Edema'].replace(['N','Y','S'],[0,1,2],inplace=True)
train_df['Status'].replace(['C','D','CL'],[0,1,2],inplace=True)
train_df['Drug'].replace(['D-penicillamine','Placebo'],[0,1],inplace=True)

# %%
train_df.dtypes
# Out:
# id                 int64
# N_Days             int64
# Drug               int64
# Age                int64
# Sex                int64
# Ascites            int64
# Hepatomegaly       int64
# Spiders            int64
# Edema              int64
# Bilirubin        float64
# Cholesterol      float64
# Albumin          float64
# Copper           float64
# Alk_Phos         float64
# SGOT             float64
# Tryglicerides    float64
# Platelets        float64
# Prothrombin      float64
# Stage            float64
# Status             int64
# dtype: object

# %%
numerical=['N_Days','Age','Bilirubin','Cholesterol','Albumin','Copper','Alk_Phos','SGOT','Tryglicerides','Platelets','Prothrombin']
categorical=['Drug','Sex','Ascites','Hepatomegaly','Spiders','Edema','Stage']

# %%
for feature in numerical:
    plt.figure(figsize=(10,8))
    sns.distplot(train_df.loc[train_df['Status']==0,feature],kde=True,color='blue',label='Status C')
    sns.distplot(train_df.loc[train_df['Status']==1,feature],kde=True,color='orange',label='Status D')
    sns.distplot(train_df.loc[train_df['Status']==2,feature],kde=True,color='purple',label='Status CL')
    plt.legend(loc='upper right')
    plt.show()
# Out:
# C:\Users\pfali\AppData\Local\Temp\ipykernel_37776\829535258.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df.loc[train_df['Status']==0,feature],kde=True,color='blue',label='Status C')
# C:\Users\pfali\AppData\Local\Temp\ipykernel_37776\829535258.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for feature in categorical:
    plt.figure(figsize=(10,8))
    sns.violinplot(x=train_df['Status'],y=train_df[feature])
    plt.show()

# %%
train_df['difference_days_age']=(train_df['Age']-train_df['N_Days'])
test_df['difference_days_age']=(test_df['Age']-test_df['N_Days'])

# %%
numerical2=['N_Days','Age','difference_days_age','Bilirubin','Cholesterol','Albumin','Copper','Alk_Phos','SGOT','Tryglicerides','Platelets','Prothrombin']
for feature in numerical2:
    plt.figure(figsize=(10,8))
    sns.distplot(train_df.loc[train_df['Status']==0,feature],kde=True,color='blue',label='Status C')
    sns.distplot(train_df.loc[train_df['Status']==1,feature],kde=True,color='orange',label='Status D')
    sns.distplot(train_df.loc[train_df['Status']==2,feature],kde=True,color='purple',label='Status CL')
    plt.legend(loc='upper right')
    plt.show()
# Out:
# C:\Users\pfali\AppData\Local\Temp\ipykernel_37776\2820990786.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df.loc[train_df['Status']==0,feature],kde=True,color='blue',label='Status C')
# C:\Users\pfali\AppData\Local\Temp\ipykernel_37776\2820990786.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for feature in categorical:
    plt.figure(figsize=(10,8))
    sns.violinplot(y=train_df['Status'], x=train_df[feature])
    plt.show()

# %%
features=train_df.columns.tolist()
features.remove('Status')
features.remove('id')

from scipy import stats

corr_dict={}
for i in features:
    corr_dict[i]=stats.pointbiserialr(train_df[i],train_df['Status'])[0]
pd.Series(corr_dict).sort_values(ascending=False)
# Out:
# Bilirubin              0.368991
# Hepatomegaly           0.350901
# Copper                 0.348268
# Prothrombin            0.316949
# Stage                  0.306757
# SGOT                   0.288217
# Spiders                0.284439
# Edema                  0.231759
# Ascites                0.218969
# Cholesterol            0.181565
# Tryglicerides          0.178713
# difference_days_age    0.171430
# Alk_Phos               0.130424
# Age                    0.087158
# Drug                  -0.025816
# Sex                   -0.115513
# Platelets             -0.132809
# Albumin               -0.249432
# N_Days                -0.324947
# dtype: float64

# %%
train_df.drop(columns=['Age','Drug'],inplace=True)
test_df.drop(columns=['Age','Drug'],inplace=True)

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

X=train_df.drop(['id','Status'],axis=1)
y=train_df[["Status"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, stratify=y, random_state=42)

random_forest_clf=RandomForestClassifier()
scaler=StandardScaler()
polynomialfeatures=PolynomialFeatures()
pipeline=Pipeline(steps=[("scaler",scaler),("polynomialfeatures",polynomialfeatures),("random_forest_clf",random_forest_clf)])
rfc={'polynomialfeatures__degree':[1,2],'random_forest_clf__n_estimators':[100,200,300],'random_forest_clf__min_samples_split':[2,3,4]}
parameter_search=GridSearchCV(pipeline,param_grid=rfc,scoring='f1_macro')
parameter_search.fit(X_train, y_train)
print("The best parameters are:", parameter_search.best_params_)
model=parameter_search.best_estimator_
print(model.score(X_train,y_train))
# Out:
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
from sklearn.metrics import f1_score

predictions=model.predict(X_test)
print(f1_score(y_test,predictions,average='macro'))
print(f1_score(y_test,predictions,average='micro'))
print(f1_score(y_test,predictions,average='weighted'))
# Out:
# 0.5916388880570279
# 0.8179059180576631
# 0.8050385948888676

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

X=train_df.drop(['id','Status'],axis=1)
y=train_df[["Status"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, stratify=y, random_state=42)

scaler=StandardScaler()

from xgboost import XGBClassifier
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

param_test1 = {
 'max_depth':range(3,10,2),
 'min_child_weight':range(1,10,2),
 'n_estimators':[100,200,300,400]   
}
gsearch1 = GridSearchCV(estimator = XGBClassifier(learning_rate =0.01, n_estimators=100, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.7, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, seed=27), 
 param_grid = param_test1, scoring='f1_macro',n_jobs=4, cv=5)
gsearch1.fit(X_train, y_train)
print("The best parameters are:", gsearch1.best_params_)
model2=gsearch1.best_estimator_
print(model2.score(X_train,y_train))
# Out:
# The best parameters are: {'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 400}
# 0.9542847503373819

# %%
predictions2=model2.predict(X_test)
print(f1_score(y_test,predictions2,average='macro'))
print(f1_score(y_test,predictions2,average='micro'))
print(f1_score(y_test,predictions2,average='weighted'))
# Out:
# 0.633308231155784
# 0.8259989883662114
# 0.8156830641328283

# %%
test_df
# Out:
#          id  N_Days Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  \
# 0      7905    3839   F       N            Y       N     N        1.2
# 1      7906    2468   F       N            N       N     N        1.1
# 2      7907      51   F       N            Y       N     Y        2.0
# 3      7908    2330   F       N            N       N     N        0.6
# 4      7909    1615   F       N            Y       N     N        1.4
# ...     ...     ...  ..     ...          ...     ...   ...        ...
# 5266  13171    2870   F       N            N       N     N        1.3
# 5267  13172    1770   F       N            N       N     N        0.5
# 5268  13173    3707   F       N            Y       N     N        0.8
# 5269  13174    1216   F       N            N       N     N        0.7
# 5270  13175    2272   F       N            N       N     N        2.0
#
#       Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# ...

# %%
test_df['Sex'].replace(['M','F'],[0,1],inplace=True)
test_df['Ascites'].replace(['N','Y'],[0,1],inplace=True)
test_df['Hepatomegaly'].replace(['N','Y'],[0,1],inplace=True)
test_df['Spiders'].replace(['N','Y'],[0,1],inplace=True)
test_df['Edema'].replace(['N','Y','S'],[0,1,2],inplace=True)
test_df=scaler.transform(test_df)
#test_df['Status'].replace(['C','D','CL'],[0,1,2],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 test_df['Spiders'].replace(['N','Y'],[0,1],inplace=True)
#       5 test_df['Edema'].replace(['N','Y','S'],[0,1,2],inplace=True)
# ----> 6 test_df=scaler.transform(test_df)
#       7 #test_df['Status'].replace(['C','D','CL'],[0,1,2],inplace=True)
#
# File ~\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
# ...

# %%
test=test_df.drop(['id'],axis=1)

y_pred=model.predict_proba(test)

y_pred=pd.DataFrame(y_pred)

# %%
test=test_df.drop(['id'],axis=1)

y_pred2=model2.predict_proba(test)

y_pred2=pd.DataFrame(y_pred2)

# %%
y_pred

# %%
submission = pd.DataFrame({"id": test_df['id'],"Status_C":y_pred[0], "Status_CL":y_pred[2],"Status_D":y_pred[1]})

submission.to_csv('C:/Users/pfali/Downloads/playground-series-s3e26/submission.csv', index=False)

# %%
submission = pd.DataFrame({"id": test_df['id'],"Status_C":y_pred2[0], "Status_CL":y_pred2[2],"Status_D":y_pred2[1]})

submission.to_csv('C:/Users/pfali/Downloads/playground-series-s3e26/submission2.csv', index=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, stratify=y, random_state=42)

ab_clf=AdaBoostClassifier()
scaler=StandardScaler()
polynomialfeatures=PolynomialFeatures()
pipeline2=Pipeline(steps=[("scaler",scaler),("polynomialfeatures",polynomialfeatures),("ab_clf",ab_clf)])
rfc2={'polynomialfeatures__degree':[1,2,3],'ab_clf__n_estimators':[100,200,300,400,500],'ab_clf__learning_rate':[0.01, 0.1, 0.25]}
parameter_search3=GridSearchCV(pipeline2,param_grid=rfc2,scoring='f1_macro')
parameter_search3.fit(X_train, y_train)
print("The best parameters are:", parameter_search3.best_params_)
model3=parameter_search3.best_estimator_
print(model3.score(X_train,y_train))
# Out:
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\pfali\Desktop\Pyton\Venv\Lib\Kaggle\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
